# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 2: Analyzing IMDb Data
#
# _Author: Kevin Markham (DC)_
#
# ---

# %% [markdown]
# For project two, you will complete a series of exercises exploring movie rating data from IMDb.
#
# For these exercises, you will be conducting basic exploratory data analysis on IMDB's movie data, looking to answer such questions as:
#
# What is the average rating per genre?
# How many different actors are in a movie?
#
# This process will help you practice your data analysis skills while becoming comfortable with Pandas.

# %% [markdown]
# ## Basic level

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read in 'imdb_1000.csv' and store it in a DataFrame named movies.

# %%
movies = pd.read_csv('./data/imdb_1000.csv')
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# #### Check the number of rows and columns.

# %%
# Answer:
movies.shape
# Out:
# (979, 6)

# %% [markdown]
# #### Check the data type of each column.

# %%
# Answer:
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %% [markdown]
# #### Calculate the average movie duration.

# %%
# Answer:
movies.agg({'duration':'mean'})
# Out:
# duration    120.979571
# dtype: float64

# %% [markdown]
# #### Sort the DataFrame by duration to find the shortest and longest movies.

# %%
# Answer:
movies.sort_values(by=['duration'])
# Out:
#      star_rating                                          title  \
# 389          8.0                                         Freaks
# 338          8.0                            Battleship Potemkin
# 258          8.1                    The Cabinet of Dr. Caligari
# 293          8.1                                      Duck Soup
# 88           8.4                                        The Kid
# 742          7.6                                      Following
# 351          8.0                                   Frankenstein
# 938          7.4                            Alice in Wonderland
# 405          7.9                      The Bride of Frankenstein
# 303          8.0                 The Nightmare Before Christmas
# 713          7.6                                The Jungle Book
# 864          7.5                                          [Rec]
# 489          7.8                     The Triplets of Belleville
# 535          7.8                                          Zelig
# ...

# %% [markdown]
# #### Create a histogram of duration, choosing an "appropriate" number of bins.

# %%
import inspect

# %%
inspect.getargvalues(hist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-eac8dc7a7f73> in <module>
# ----> 1 inspect.getargvalues(hist)
#
# NameError: name 'hist' is not defined

# %%
# Answer:
movies.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000230474F36D8>,
# ...
#       dtype=object)

# %% [markdown]
# #### Use a box plot to display that same data.

# %%
# Answer:
movies.boxplot()

# %% [markdown]
# ## Intermediate level

# %% [markdown]
# #### Count how many movies have each of the content ratings.

# %%
# Answer:
movies.groupby('content_rating').agg({'title':'count'})
# Out:
#                 title
# content_rating
# APPROVED           47
# G                  32
# GP                  3
# NC-17               7
# NOT RATED          65
# PASSED              7
# PG                123
# PG-13             189
# R                 460
# TV-MA               1
# UNRATED            38
# X                   4

# %% [markdown]
# #### Use a visualization to display that same data, including a title and x and y labels.

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 6 columns):
# star_rating       979 non-null float64
# title             979 non-null object
# content_rating    976 non-null object
# genre             979 non-null object
# duration          979 non-null int64
# actors_list       979 non-null object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 46.0+ KB

# %%
ax[0,0]

# %%
# Answer:
axes = movies.groupby('content_rating').agg({'title':'count'}).hist()
axes[0,0].set_xlabel('Duration in Minutes')
axes[0,0].set_ylabel('Titles')
axes[0,0].set_title('Distribution of Movie Duration')
# Out:
# Text(0.5, 1.0, 'Distribution of Movie Duration')

# %% [markdown]
# #### Convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP.

# %%
movies = movies.replace(['NOT RATED','APPROVED','PASSED','GP'],'UNRATED')

# %% [markdown]
# #### Convert the following content ratings to "NC-17": X, TV-MA.

# %%
# Answer:
#movies.loc[movies.loc[:,'content_rating'].isin(['X','TV-MA']),]
#movies.loc[movies.loc[:,'content_rating'].isin(['X','TV-MA']),].content_rating
#movies.content_rating.replace(movies.loc[movies.loc[:,'content_rating'].isin(['X','TV-MA']),].content_rating,'NC-17')
movies.content_rating = movies.content_rating.replace(movies.loc[movies.loc[:,'content_rating'].isin(['X','TV-MA']),].content_rating,'NC-17')
movies.loc[movies.loc[:,'content_rating'].isin(['NC-17']),]
# Out:
#      star_rating                            title content_rating   genre  \
# 86           8.4               A Clockwork Orange          NC-17   Crime
# 219          8.1  Who's Afraid of Virginia Woolf?          NC-17   Drama
# 387          8.0                  Midnight Cowboy          NC-17   Drama
# 456          7.9        Blue Is the Warmest Color          NC-17   Drama
# 486          7.8                     Evil Dead II          NC-17  Comedy
# 604          7.7                  Mysterious Skin          NC-17   Drama
# 715          7.6                    Man Bites Dog          NC-17  Comedy
# 755          7.6                    Lust, Caution          NC-17   Drama
# 796          7.6                    The Evil Dead          NC-17  Horror
# 913          7.5                         Suspiria          NC-17  Horror
# 915          7.5                    Bad Education          NC-17   Crime
# 972          7.4                   Blue Valentine          NC-17   Drama
#
# ...

# %% [markdown]
# #### Count the number of missing values in each column.

# %%
# Answer:
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %% [markdown]
# #### If there are missing values: examine them, then fill them in with "reasonable" values.

# %%
# Answer:
movies.loc[movies.loc[:,'content_rating'].isnull(),]
#movies.content_rating.fillna(value='Unavailable')
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %% [markdown]
# #### Calculate the average star rating for movies 2 hours or longer, and compare that with the average star rating for movies shorter than 2 hours.

# %%
# Answer: Movies longer than 120 mins have a higher average rating
movies.loc[movies.loc[:,'duration'] > 120,'star_rating'].agg('mean') >= movies.loc[movies.loc[:,'duration'] < 120,'star_rating'].agg('mean')
# Out:
# True

# %% [markdown]
# #### Use a visualization to detect whether there is a relationship between duration and star rating.

# %%
# Answer:
ax = movies.plot(kind='scatter',x='duration',y='star_rating')

# %% [markdown]
# #### Calculate the average duration for each genre.

# %%
# Answer:
movies.groupby('genre').agg({'duration':'mean'})
# Out:
#              duration
# genre
# Action     126.485294
# Adventure  134.840000
# Animation   96.596774
# Biography  131.844156
# Comedy     107.602564
# Crime      122.298387
# Drama      126.539568
# Family     107.500000
# Fantasy    112.000000
# Film-Noir   97.333333
# History     66.000000
# Horror     102.517241
# Mystery    115.625000
# Sci-Fi     109.000000
# Thriller   114.200000
# Western    136.666667

# %% [markdown]
# ## Advanced level

# %% [markdown]
# #### Visualize the relationship between content rating and duration.

# %%
# Answer:
ax = movies.groupby('content_rating').agg({'duration':'mean'}).sort_values(by='duration',ascending=False).plot(kind='barh')

# %% [markdown]
# #### Find the title of the movie with the highest star rating in each genre

# %%
# Answer:

movies.groupby('genre')['star_rating'].max()
# Out:
# genre
# Action       9.0
# Adventure    8.9
# Animation    8.6
# Biography    8.9
# Comedy       8.6
# Crime        9.3
# Drama        8.9
# Family       7.9
# Fantasy      7.7
# Film-Noir    8.3
# History      8.0
# Horror       8.6
# Mystery      8.6
# Sci-Fi       8.2
# Thriller     8.0
# Western      8.9
# Name: star_rating, dtype: float64

# %% [markdown]
# #### Check if there are multiple movies with the same title, and if so, determine if they are actually duplicates.

# %%
# Answer: The four repeats are Dracula, Les Mis, The Girl with the Dragon Tatoo, and True Grit. They're not really dupes
#Method 1
movies.groupby('title').agg({'title':'count'})
dupe_movies = movies.groupby('title').agg({'title':'count'}) > 1
dupe_movies.columns = ['instances']
dupe_movies[dupe_movies.instances == True]
#Method 2
movies.title.value_counts() > 1
# Out:
# True Grit                                             True
# Les Miserables                                        True
# Dracula                                               True
# The Girl with the Dragon Tattoo                       True
# The Social Network                                   False
# Million Dollar Baby                                  False
# Lagaan: Once Upon a Time in India                    False
# The Nightmare Before Christmas                       False
# The Theory of Everything                             False
# Good Night, and Good Luck.                           False
# Ferris Bueller's Day Off                             False
# Crash                                                False
# Dawn of the Dead                                     False
# Menace II Society                                    False
# The Simpsons Movie                                   False
# Saving Private Ryan                                  False
# ...

# %%
#movies.title.isin(['Dracula','Les Miserables','The Girl with the Dragon Tattoo','True Grit'])
movies.loc[movies.title.isin(['Dracula','Les Miserables','The Girl with the Dragon Tattoo','True Grit']),]
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 949    False
# 950    False
# 951    False
# 952    False
# 953    False
# 954    False
# 955    False
# 956    False
# 957    False
# 958    False
# 959    False
# 960    False
# 961    False
# 962    False
# 963    False
# 964    False
# 965    False
# 966    False
# 967    False
# 968    False
# 969    False
# 970    False
# 971    False
# 972    False
# 973    False
# 974    False
# 975    False
# 976    False
# 977    False
# 978    False
# Name: title, Length: 979, dtype: bool

# %% [markdown]
# #### Calculate the average star rating for each genre, but only include genres with at least 10 movies

# %% [markdown]
# **You only need to choose one of the options below.** However, solving for multiple options would count as "extra credit" that could e.g. raise your score from a 2 ("meets expectations") to a 3 ("exceeds expectations").

# %% [markdown]
# #### Option 1: manually create a list of relevant genres, then filter using that list

# %%
# Answer:

# %% [markdown]
# #### Option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# Answer:
popular_genres = pd.DataFrame(movies.genre.value_counts())
popular_genres['counts'] = popular_genres.index
popular_genres.columns = ['counts','genre']
popular_genres = list(popular_genres.genre)
popular_genres
movies.loc[movies.loc[:,'genre'].isin(popular_genres)]
# Out:
#      star_rating                                              title  \
# 0            9.3                           The Shawshank Redemption
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %% [markdown]
# #### Option 3: calculate the average star rating for all genres, then filter using a boolean Series

# %%
# Answer:

# %% [markdown]
# #### Option 4: aggregate by count and mean, then filter using the count

# %%
# Answer:

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Figure out something "interesting" using the actors data!
